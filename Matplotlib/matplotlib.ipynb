# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,90,100)
y=np.sin(x)
z=np.cos(x)

# %%
print(x)
# Out:
# [ 0.          0.90909091  1.81818182  2.72727273  3.63636364  4.54545455
#   5.45454545  6.36363636  7.27272727  8.18181818  9.09090909 10.
#  10.90909091 11.81818182 12.72727273 13.63636364 14.54545455 15.45454545
#  16.36363636 17.27272727 18.18181818 19.09090909 20.         20.90909091
#  21.81818182 22.72727273 23.63636364 24.54545455 25.45454545 26.36363636
#  27.27272727 28.18181818 29.09090909 30.         30.90909091 31.81818182
#  32.72727273 33.63636364 34.54545455 35.45454545 36.36363636 37.27272727
#  38.18181818 39.09090909 40.         40.90909091 41.81818182 42.72727273
#  43.63636364 44.54545455 45.45454545 46.36363636 47.27272727 48.18181818
#  49.09090909 50.         50.90909091 51.81818182 52.72727273 53.63636364
#  54.54545455 55.45454545 56.36363636 57.27272727 58.18181818 59.09090909
#  60.         60.90909091 61.81818182 62.72727273 63.63636364 64.54545455
#  65.45454545 66.36363636 67.27272727 68.18181818 69.09090909 70.
#  70.90909091 71.81818182 72.72727273 73.63636364 74.54545455 75.45454545
#  76.36363636 77.27272727 78.18181818 79.09090909 80.         80.90909091
#  81.81818182 82.72727273 83.63636364 84.54545455 85.45454545 86.36363636
#  87.27272727 88.18181818 89.09090909 90.        ]

# %%
print(y)
# Out:
# [ 0.          0.78894546  0.96955595  0.40256749 -0.47483011 -0.98609877
#  -0.73701276  0.0803643   0.83577457  0.94674118  0.32770071 -0.54402111
#  -0.99626264 -0.68031241  0.16020873  0.87719715  0.91780205  0.25071407
#  -0.6096929  -0.99998181 -0.61921119  0.23901679  0.91294525  0.88292578
#   0.17210559 -0.67142066 -0.9972322  -0.55410437  0.31627868  0.94278761
#   0.84233795  0.09238378 -0.72880508 -0.98803162 -0.48541312  0.3914946
#   0.96653119  0.79630115  0.01206435 -0.78147495 -0.97243958 -0.41358178
#   0.46417799  0.98402239  0.74511316 -0.06833312 -0.82908954 -0.95055695
#  -0.33907504  0.53385866  0.99514807  0.68910513 -0.14828855 -0.87134085
#  -0.92252527 -0.26237485  0.60008587  0.99983625  0.62863935 -0.22728473
#  -0.90795556 -0.88852588 -0.1839774   0.66243119  0.99805661  0.56410698
#  -0.30481062 -0.93869682 -0.84877873 -0.10438982  0.72049132  0.98982066
#   0.49592547 -0.38036473 -0.96336575 -0.80354092 -0.02412695  0.77389068
#   0.97518168  0.42453588 -0.45345831 -0.98180279 -0.75310511  0.056292
#   0.82228383  0.95423436  0.35040001 -0.52361851 -0.99388865 -0.69779754
#   0.13634679  0.86535772  0.92711421  0.27399745 -0.59039149 -0.99954517
#  -0.63797601  0.21551958  0.90283372  0.89399666]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,z)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel("degree-->")
plt.ylabel("Values-->")
plt.title("Sin Wave")
# Out:
# Text(0.5, 1.0, 'Sin Wave')

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(-10,10,20)
y=x**2
plt.plot(x,y,'g*')

# %%
x=np.linspace(-10,10,20)
plt.plot(x,np.sin(x),"r--")
plt.plot(np.cos(x),np.sin(x),'g')
plt.show()

# %%
fig=plt.figure()
axis=fig.add_axes([0,0,1,1])
Batsman=["Kohli","Rohit","ABD","Rahul"]
Runs=[140,100,130,30]
axis.bar(Batsman,Runs)
plt.xlabel("Batsmans")
plt.ylabel("Runs")
plt.show()

# %%
fig=plt.figure()
axis=fig.add_axes([0,0,1,1])
Batsman=["Kohli","Rohit","ABD","Rahul"]
Runs=[140,100,130,30]
axis.pie(Runs,labels=Batsman)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,100,100)
y=np.sin(x)
z=np.cos(x)
fig=plt.figure()
axis=fig.add_axes([0,0,1,1])
axis.scatter(x,y)
axis.scatter(x,z)

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,100,100)
y=np.sin(x)
z=np.cos(x)
fig=plt.figure()
axis=plt.axes(projection='3d')
z=np.linspace(0,100,100)
x=np.sin(x)
y=np.cos(x)
axis.scatter(x,y,z)
